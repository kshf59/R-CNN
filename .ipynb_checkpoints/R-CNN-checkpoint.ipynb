# %%
# !python --version
# Out:
# Python 3.7.0

# %% [markdown]
# #### 파이썬 코코 데이터셋 load(Linux, Window 구분)

# %% [markdown]
# #### linux
# #### !pip install "git+https://github.com/philferriere/cocoapi.git#egg=pycocotools&subdirectory=PythonAPI"
# #### window
# #### !pip install pycocotools-windows

# %%
from pycocotools.coco import COCO
import os
import numpy as np
import cv2

# %%
import PIL.Image as Image

# %%
dataDir = '../coco'
annVal = os.path.join(dataDir,  'instances_val2017.json')

# %%
coco = COCO(annVal)
print(coco)
# Out:
# loading annotations into memory...
# Done (t=0.53s)
# creating index...
# index created!
# <pycocotools.coco.COCO object at 0x0000014860260898>

# %%
img_id = coco.getImgIds()[0]

# %%
img_info = coco.loadImgs(img_id)[0]

# %%
tt = cv2.imread(os.path.join(dataDir, img_info['file_name']))

# %%
coco.loadImgs(coco.imgs)[0]
# Out:
# {'license': 4,
#  'file_name': '000000397133.jpg',
#  'coco_url': 'http://images.cocodataset.org/val2017/000000397133.jpg',
#  'height': 427,
#  'width': 640,
#  'date_captured': '2013-11-14 17:02:52',
#  'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg',
#  'id': 397133}

# %% [markdown]
# coco.loadImgs(coco.getImgIds())

# %%
import tensorflow as tf
